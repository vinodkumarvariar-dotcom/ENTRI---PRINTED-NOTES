# %% [markdown]
# # DataFrame

# %% [markdown]
# ## What is DataFrame?

# %%
import pandas as pd

# %%
data={"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],      
      "score":[90,80,85,75,95,60,65],      
      "sport":["Wrestling","Football","Skiing","Swimming","Tennis",
               "Karete","Surfing"],      
      "sex":["M","M","M","M","F","F","F"]}

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       name  score      sport sex
# 0     Bill     90  Wrestling   M
# 1      Tom     80   Football   M
# 2      Tim     85     Skiing   M
# 3     John     75   Swimming   M
# 4     Alex     95     Tennis   F
# 5  Vanessa     60     Karete   F
# 6     Kate     65    Surfing   F

# %%
df.tail(3)
# Out:
#       name  score    sport sex
# 4     Alex     95   Tennis   F
# 5  Vanessa     60   Karete   F
# 6     Kate     65  Surfing   F

# %%
df.columns
# Out:
# Index(['name', 'score', 'sport', 'sex'], dtype='object')

# %%
df.shape
# Out:
# (7, 4)

# %%
df.dtypes
# Out:
# name     object
# score     int64
# sport    object
# sex      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   score   7 non-null      int64
#  2   sport   7 non-null      object
#  3   sex     7 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 356.0+ bytes

# %%
df.isnull().sum()
# Out:
# name     0
# score    0
# sport    0
# sex      0
# dtype: int64

# %%
# adding a new column
values=[18,19,20,18,17,17,18]
df['Age'] = values

# %%
df
# Out:
#       name  score      sport sex  Age
# 0     Bill     90  Wrestling   M   18
# 1      Tom     80   Football   M   19
# 2      Tim     85     Skiing   M   20
# 3     John     75   Swimming   M   18
# 4     Alex     95     Tennis   F   17
# 5  Vanessa     60     Karete   F   17
# 6     Kate     65    Surfing   F   18

# %%
df.iloc[1:4]
# Out:
#    name  score     sport sex
# 1   Tom     80  Football   M
# 2   Tim     85    Skiing   M
# 3  John     75  Swimming   M

# %%
df.loc[0:2,['name','score']]
# Out:
#    name  score
# 0  Bill     90
# 1   Tom     80
# 2   Tim     85

# %%
df.iloc[0:2,0:2]
# Out:
#    name  score
# 0  Bill     90
# 1   Tom     80

# %%
df[['name','score']]
# Out:
#       name  score
# 0     Bill     90
# 1      Tom     80
# 2      Tim     85
# 3     John     75
# 4     Alex     95
# 5  Vanessa     60
# 6     Kate     65

# %%
df1 = df[['name','score']]

# %%
df1.shape
# Out:
# (7, 2)

# %%
df=pd.DataFrame(data,columns=["name","sport","sex","score"])
df
# Out:
#       name      sport sex  score
# 0     Bill  Wrestling   M     90
# 1      Tom   Football   M     80
# 2      Tim     Skiing   M     85
# 3     John   Swimming   M     75
# 4     Alex     Tennis   F     95
# 5  Vanessa     Karete   F     60
# 6     Kate    Surfing   F     65

# %%
df.shape
# Out:
# (7, 4)

# %%
df.head()
# Out:
#    name      sport sex  score
# 0  Bill  Wrestling   M     90
# 1   Tom   Football   M     80
# 2   Tim     Skiing   M     85
# 3  John   Swimming   M     75
# 4  Alex     Tennis   F     95

# %%
df.tail()
# Out:
#       name     sport sex  score
# 2      Tim    Skiing   M     85
# 3     John  Swimming   M     75
# 4     Alex    Tennis   F     95
# 5  Vanessa    Karete   F     60
# 6     Kate   Surfing   F     65

# %%
df.tail(3)
# Out:
#       name    sport sex  score
# 4     Alex   Tennis   F     95
# 5  Vanessa   Karete   F     60
# 6     Kate  Surfing   F     65

# %%
df.head(2)
# Out:
#    name      sport sex  score
# 0  Bill  Wrestling   M     90
# 1   Tom   Football   M     80

# %%
df
# Out:
#       name  score      sport sex
# 0     Bill     90  Wrestling   M
# 1      Tom     80   Football   M
# 2      Tim     85     Skiing   M
# 3     John     75   Swimming   M
# 4     Alex     95     Tennis   F
# 5  Vanessa     60     Karete   F
# 6     Kate     65    Surfing   F

# %%
data
# Out:
# {'name': ['Bill', 'Tom', 'Tim', 'John', 'Alex', 'Vanessa', 'Kate'],
#  'score': [90, 80, 85, 75, 95, 60, 65],
#  'sport': ['Wrestling',
#   'Football',
#   'Skiing',
#   'Swimming',
#   'Tennis',
#   'Karete',
#   'Surfing'],
#  'sex': ['M', 'M', 'M', 'M', 'F', 'F', 'F']}

# %%
df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"])
df
# Out:
#       name      sport gender  score  age
# 0     Bill  Wrestling    NaN     90  NaN
# 1      Tom   Football    NaN     80  NaN
# 2      Tim     Skiing    NaN     85  NaN
# 3     John   Swimming    NaN     75  NaN
# 4     Alex     Tennis    NaN     95  NaN
# 5  Vanessa     Karete    NaN     60  NaN
# 6     Kate    Surfing    NaN     65  NaN

# %%
df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"],
                index=["one","two","three","four","five","six","seven"])
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling    NaN     90  NaN
# two        Tom   Football    NaN     80  NaN
# three      Tim     Skiing    NaN     85  NaN
# four      John   Swimming    NaN     75  NaN
# five      Alex     Tennis    NaN     95  NaN
# six    Vanessa     Karete    NaN     60  NaN
# seven     Kate    Surfing    NaN     65  NaN

# %%
df.loc['one':'four']
# Out:
#        name      sport gender  score  age
# one    Bill  Wrestling    NaN     90  NaN
# two     Tom   Football    NaN     80  NaN
# three   Tim     Skiing    NaN     85  NaN
# four   John   Swimming    NaN     75  NaN

# %%
df["sport"]
# Out:
# one      Wrestling
# two       Football
# three       Skiing
# four      Swimming
# five        Tennis
# six         Karete
# seven      Surfing
# Name: sport, dtype: object

# %%
# my_columns=["name","sport"]
# df[my_columns]

# %%
df.loc[:,["name","sport"]]
# Out:
#           name      sport
# one       Bill  Wrestling
# two        Tom   Football
# three      Tim     Skiing
# four      John   Swimming
# five      Alex     Tennis
# six    Vanessa     Karete
# seven     Kate    Surfing

# %%
df['sport']
# Out:
# 0    Wrestling
# 1     Football
# 2       Skiing
# 3     Swimming
# 4       Tennis
# 5       Karete
# 6      Surfing
# Name: sport, dtype: object

# %%
df.loc[["one"]]
# Out:
#      name      sport gender  score  age
# one  Bill  Wrestling    NaN     90  NaN

# %%
df.loc[["one":"two"]]

# %%
df["age"]=18

# %%
df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"], 
                index=["one","two","three","four","five","six","seven"])
values=[18,19,20,18,17,17,18]
df["age"]=values
#df["age"]=18
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling    NaN     90   18
# two        Tom   Football    NaN     80   19
# three      Tim     Skiing    NaN     85   20
# four      John   Swimming    NaN     75   18
# five      Alex     Tennis    NaN     95   17
# six    Vanessa     Karete    NaN     60   17
# seven     Kate    Surfing    NaN     65   18

# %%
df["pass"]=df['score']>=70
df
# Out:
#           name      sport gender  score  age   pass
# one       Bill  Wrestling    NaN     90   18   True
# two        Tom   Football    NaN     80   19   True
# three      Tim     Skiing    NaN     85   20   True
# four      John   Swimming    NaN     75   18   True
# five      Alex     Tennis    NaN     95   17   True
# six    Vanessa     Karete    NaN     60   17  False
# seven     Kate    Surfing    NaN     65   18  False

# %%
df.drop(columns=['pass'],inplace=True)

# %%
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling    NaN     90   18
# two        Tom   Football    NaN     80   19
# three      Tim     Skiing    NaN     85   20
# four      John   Swimming    NaN     75   18
# five      Alex     Tennis    NaN     95   17
# six    Vanessa     Karete    NaN     60   17
# seven     Kate    Surfing    NaN     65   18

# %%
df = df.drop(columns = ['age'])

# %%
df
# Out:
#           name      sport gender  score
# one       Bill  Wrestling    NaN     90
# two        Tom   Football    NaN     80
# three      Tim     Skiing    NaN     85
# four      John   Swimming    NaN     75
# five      Alex     Tennis    NaN     95
# six    Vanessa     Karete    NaN     60
# seven     Kate    Surfing    NaN     65

# %%
# del df["pass"]
# df

# %%
df.loc[df['name']=='Tom','sport'] = 'Tennis'

# %%
df.loc[df['name']=='Tom','sport'] = 'karate'

# %%
df.loc[df['name'] == 'Tom', 'sport'] = 'Karate'

# %%
df
# Out:
#       name  score      sport sex  Age
# 0     Bill     90  Wrestling   M   18
# 1      Tom     80     Tennis   M   19
# 2      Tim     85     Skiing   M   20
# 3     John     75   Swimming   M   18
# 4     Alex     95     Tennis   F   17
# 5  Vanessa     60     Karete   F   17
# 6     Kate     65    Surfing   F   18

# %%
df.shape
# Out:
# (7, 4)

# %%
df.drop('sex',axis = 1)
# Out:
#       name  score      sport  Age
# 0     Bill     90  Wrestling   18
# 1      Tom     80     Tennis   19
# 2      Tim     85     Skiing   20
# 3     John     75   Swimming   18
# 4     Alex     95     Tennis   17
# 5  Vanessa     60     Karete   17
# 6     Kate     65    Surfing   18

# %%
df.drop('sex',axis = 1)
# Out:
#       name  score      sport
# 0     Bill     90  Wrestling
# 1      Tom     80     Karate
# 2      Tim     85     Skiing
# 3     John     75   Swimming
# 4     Alex     95     Tennis
# 5  Vanessa     60     Karete
# 6     Kate     65    Surfing

# %%
df.drop(6)
# Out:
#       name  score      sport sex  Age
# 0     Bill     90  Wrestling   M   18
# 1      Tom     80     Tennis   M   19
# 2      Tim     85     Skiing   M   20
# 3     John     75   Swimming   M   18
# 4     Alex     95     Tennis   F   17
# 5  Vanessa     60     Karete   F   17

# %%
df.columns
# Out:
# Index(['name', 'score', 'sport', 'sex'], dtype='object')

# %%
df.dtypes
# Out:
# name     object
# score     int64
# sport    object
# sex      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   score   7 non-null      int64
#  2   sport   7 non-null      object
#  3   sex     7 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 356.0+ bytes

# %%
df.describe()
# Out:
#            score
# count   7.000000
# mean   78.571429
# std    12.817399
# min    60.000000
# 25%    70.000000
# 50%    80.000000
# 75%    87.500000
# max    95.000000
