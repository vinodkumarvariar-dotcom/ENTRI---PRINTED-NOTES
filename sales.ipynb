# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1

# %%
df = pd.read_csv('data/sales_data_sample.csv',encoding='latin1')
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.tail(3)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE COUNTRY  \
# 2820     C/ Moralzarzal, 86           NaN    Madrid   NaN      28034   Spain
# 2821  1 rue Alsace-Lorraine           NaN  Toulouse   NaN      31000  France
# 2822     8616 Spinnaker Dr.           NaN    Boston    MA      51003     USA
#
#      TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# ...

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.shape  # (row,column)
# Out:
# (2823, 25)

# %%
# statistical summary
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.info()  # summary of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %% [markdown]
# # to find unique values in a specefic column -- unique()

# %%
df['YEAR_ID'].unique()
# Out:
# array([2003, 2004, 2005])

# %%
df['COUNTRY'].unique()
# Out:
# array(['USA', 'France', 'Norway', 'Australia', 'Finland', 'Austria', 'UK',
#        'Spain', 'Sweden', 'Singapore', 'Canada', 'Japan', 'Italy',
#        'Denmark', 'Belgium', 'Philippines', 'Germany', 'Switzerland',
#        'Ireland'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %% [markdown]
# # 2   sales by each productline

# %%
df['PRODUCTLINE'].unique()
# Out:
# array(['Motorcycles', 'Classic Cars', 'Trucks and Buses', 'Vintage Cars',
#        'Planes', 'Ships', 'Trains'], dtype=object)

# %%
df['PRODUCTLINE'].value_counts()  # number of rows for each productline
# Out:
# PRODUCTLINE
# Classic Cars        967
# Vintage Cars        607
# Motorcycles         331
# Planes              306
# Trucks and Buses    301
# Ships               234
# Trains               77
# Name: count, dtype: int64

# %%
df[df['PRODUCTLINE']=='Motorcycles']
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2452        10356               26     100.00                4  3937.70
# 2453        10365               44     100.00                2  4984.32
# 2454        10375               49     100.00                8  5406.66
# 2455        10390               22     100.00               13  3491.18
# 2456        10403               31      68.34                3  2118.54
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df[['PRODUCTLINE','SALES']]
# Out:
#       PRODUCTLINE    SALES
# 0     Motorcycles  2871.00
# 1     Motorcycles  2765.90
# 2     Motorcycles  3884.34
# 3     Motorcycles  3746.70
# 4     Motorcycles  5205.27
# ...           ...      ...
# 2818        Ships  2244.40
# 2819        Ships  3978.51
# 2820        Ships  5417.57
# 2821        Ships  2116.16
# 2822        Ships  3079.44
#
# [2823 rows x 2 columns]

# %%
df.groupby('PRODUCTLINE')['SALES'].sum().reset_index()
# Out:
#         PRODUCTLINE       SALES
# 0      Classic Cars  3919615.66
# 1       Motorcycles  1166388.34
# 2            Planes   975003.57
# 3             Ships   714437.13
# 4            Trains   226243.47
# 5  Trucks and Buses  1127789.84
# 6      Vintage Cars  1903150.84

# %%
df.groupby('PRODUCTLINE')['SALES'].mean().reset_index()
# Out:
#         PRODUCTLINE        SALES
# 0      Classic Cars  4053.377104
# 1       Motorcycles  3523.831843
# 2            Planes  3186.286176
# 3             Ships  3053.150128
# 4            Trains  2938.226883
# 5  Trucks and Buses  3746.810100
# 6      Vintage Cars  3135.339110

# %%
sales_by_prolile = df.groupby('PRODUCTLINE')['SALES'].mean().reset_index()
sales_by_prolile.plot(kind ='bar')
# Out:
# <Axes: >

# %%
df.groupby('PRODUCTLINE')['SALES'].sum().reset_index()
# Out:
#         PRODUCTLINE       SALES
# 0      Classic Cars  3919615.66
# 1       Motorcycles  1166388.34
# 2            Planes   975003.57
# 3             Ships   714437.13
# 4            Trains   226243.47
# 5  Trucks and Buses  1127789.84
# 6      Vintage Cars  1903150.84

# %% [markdown]
# # 3 top 5 customers based on sales

# %%
df[['CUSTOMERNAME','SALES']].sort_values(by = 'SALES',ascending=False).head()
# Out:
#                       CUSTOMERNAME    SALES
# 598      The Sharp Gifts Warehouse  14082.8
# 744   Online Diecast Creations Co.  12536.5
# 53           Euro Shopping Channel  12001.0
# 1062         Euro Shopping Channel  11887.8
# 104          UK Collectables, Ltd.  11886.6

# %%
top_customers = df[['CUSTOMERNAME','SALES']].sort_values(by='SALES',ascending=False)
top_customers.head(10)
# Out:
#                       CUSTOMERNAME    SALES
# 598      The Sharp Gifts Warehouse  14082.8
# 744   Online Diecast Creations Co.  12536.5
# 53           Euro Shopping Channel  12001.0
# 1062         Euro Shopping Channel  11887.8
# 104          UK Collectables, Ltd.  11886.6
# 1995                   Mini Caravy  11739.7
# 44    Mini Gifts Distributors Ltd.  11623.7
# 1133               Mini Wheels Co.  11336.7
# 188             Muscle Machine Inc  11279.2
# 30         Dragon Souveniers, Ltd.  10993.5

# %% [markdown]
# # writing data

# %%
top_customers.to_csv('customers.csv',index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %% [markdown]
# # 4 monthly sales

# %%
df['ORDERDATE'] = pd.to_datetime(df['ORDERDATE'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   datetime64[ns]
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df['Month'] = df['ORDERDATE'].dt.to_period('M')

# %%
df['Month']
# Out:
# 0       2003-02
# 1       2003-05
# 2       2003-07
# 3       2003-08
# 4       2003-10
#          ...
# 2818    2004-12
# 2819    2005-01
# 2820    2005-03
# 2821    2005-03
# 2822    2005-05
# Name: Month, Length: 2823, dtype: period[M]

# %%
df1 = df[['Month','SALES']]
df1.head()
# Out:
#      Month    SALES
# 0  2003-02  2871.00
# 1  2003-05  2765.90
# 2  2003-07  3884.34
# 3  2003-08  3746.70
# 4  2003-10  5205.27

# %% [markdown]
# # 5   count the number of orders for each  status

# %%
df['STATUS'].unique()
# Out:
# array(['Shipped', 'Disputed', 'In Process', 'Cancelled', 'On Hold',
#        'Resolved'], dtype=object)

# %%
df.groupby('STATUS')['ORDERNUMBER'].count().reset_index()
# Out:
#        STATUS  ORDERNUMBER
# 0   Cancelled           60
# 1    Disputed           14
# 2  In Process           41
# 3     On Hold           44
# 4    Resolved           47
# 5     Shipped         2617

# %%
df = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
df
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df1 = pd.DataFrame({'Name': ['David', 'Eva'], 'Age': [22, 28]})
df1
# Out:
#     Name  Age
# 0  David   22
# 1    Eva   28

# %%
pd.concat([df,df1],axis=1)
# Out:
#     Name  Age   Name  Age
# 0  Alice   25  David   22
# 1    Bob   30    Eva   28

# %%
new_df = pd.concat([df,df1],ignore_index=True)
new_df
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30
# 2  David   22
# 3    Eva   28

# %%
df = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})


new_data = pd.DataFrame({'Name': ['David', 'Eva'], 'Age': [22, 28]})


df = pd.concat([df, new_data], ignore_index=True)

print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30
# 2  David   22
# 3    Eva   28

# %%
# Count = df['STATUS'].value_counts().reset_index()
# Count
# Out:
#        STATUS  count
# 0     Shipped   2617
# 1   Cancelled     60
# 2    Resolved     47
# 3     On Hold     44
# 4  In Process     41
# 5    Disputed     14

# %%
df.groupby("STATUS")['ORDERNUMBER'].count()
# Out:
# STATUS
# Cancelled       60
# Disputed        14
# In Process      41
# On Hold         44
# Resolved        47
# Shipped       2617
# Name: ORDERNUMBER, dtype: int64
